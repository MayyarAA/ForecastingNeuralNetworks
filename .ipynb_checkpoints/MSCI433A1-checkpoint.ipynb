# %% [markdown]
# <a href="https://colab.research.google.com/github/MayyarAA/ForecastingNeuralNetworks/blob/main/MSCI433A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import scipy
import pandas
import matplotlib.pyplot as plt
import sklearn    
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1 = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/StateData.csv")
data1.head()
# Out:
#    Population  Income  Illiteracy  LifeExp  ...    Area  Longitude  Latitude  Region
# 0        3615    3624         2.1    69.05  ...   50708   -86.7509   32.5901   South
# 1         365    6315         1.5    69.31  ...  566432  -127.2500   49.2500    West
# 2        2212    4530         1.8    70.55  ...  113417  -111.6250   34.2192    West
# 3        2110    3378         1.9    70.66  ...   51945   -92.2992   34.7336   South
# 4       21198    5114         1.1    71.71  ...  156361  -119.7730   36.5341    West
#
# [5 rows x 11 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Population      50 non-null     int64
#  1   Income          50 non-null     int64
#  2   Illiteracy      50 non-null     float64
#  3   LifeExp         50 non-null     float64
#  4   Murder          50 non-null     float64
#  5   HighSchoolGrad  50 non-null     float64
#  6   Frost           50 non-null     int64
#  7   Area            50 non-null     int64
#  8   Longitude       50 non-null     float64
#  9   Latitude        50 non-null     float64
#  10  Region          50 non-null     object
# dtypes: float64(6), int64(4), object(1)
# memory usage: 4.4+ KB

# %%
#a)i
statedata = data1
#statedata['Region'] = pandas.to_pickle (statedata['Region'],errors='coerce')
#statedata.head()
plt.scatter(x=statedata["Longitude"],y=statedata["Latitude"])

# %%
#a)ii
regions_highschoolgradmean = statedata.groupby(by="Region").mean()
regions_highschoolgradmean
# Out:
#                 Population       Income  ...   Longitude   Latitude
# Region                                   ...
# North Central  4803.000000  4611.083333  ...  -92.562783  42.171567
# Northeast      5495.111111  4570.222222  ...  -72.756411  42.535956
# South          4208.125000  4011.937500  ...  -85.174487  34.610344
# West           2915.307692  4702.615385  ... -114.988769  40.606854
#
# [4 rows x 10 columns]

# %%
#1.a)iii
#box plot for murder in each region 
#df_box = statedata_region.iloc[:,4]
#df_box
murderfor_southregion = statedata.loc[statedata['Region']=='South','Murder']

murderfor_westhregion = statedata.loc[statedata['Region']=='West','Murder']

murderfor_northeasthregion = statedata.loc[statedata['Region']=='Northeast','Murder']

murderfor_northcentralregion = statedata.loc[statedata['Region']=='North Central','Murder']
plt.boxplot([murderfor_southregion,murderfor_westhregion,murderfor_northeasthregion,murderfor_northcentralregion],labels=['South','West','Northeast','North Central'])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# {'boxes': [<matplotlib.lines.Line2D at 0x7f357951da10>,
#   <matplotlib.lines.Line2D at 0x7f3574aa7110>,
#   <matplotlib.lines.Line2D at 0x7f3574a39610>,
#   <matplotlib.lines.Line2D at 0x7f3574a48bd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3574a99b10>,
#   <matplotlib.lines.Line2D at 0x7f3574aa2090>,
#   <matplotlib.lines.Line2D at 0x7f3574ab00d0>,
#   <matplotlib.lines.Line2D at 0x7f3574ab0610>,
#   <matplotlib.lines.Line2D at 0x7f3574a42650>,
#   <matplotlib.lines.Line2D at 0x7f3574a42b90>,
#   <matplotlib.lines.Line2D at 0x7f3574a52bd0>,
#   <matplotlib.lines.Line2D at 0x7f3574a59150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3574aa2b50>,
#   <matplotlib.lines.Line2D at 0x7f3574a390d0>,
#   <matplotlib.lines.Line2D at 0x7f3574a48690>,
#   <matplotlib.lines.Line2D at 0x7f3574a59bd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3574aa25d0>,
#   <matplotlib.lines.Line2D at 0x7f3574ab0b50>,
#   <matplotlib.lines.Line2D at 0x7f3574a48150>,
#   <matplotlib.lines.Line2D at 0x7f3574a59690>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3574a99050>,
#   <matplotlib.lines.Line2D at 0x7f3574a995d0>,
#   <matplotlib.lines.Line2D at 0x7f3574aa7610>,
#   <matplotlib.lines.Line2D at 0x7f3574aa7b90>,
#   <matplotlib.lines.Line2D at 0x7f3574a39b10>,
#   <matplotlib.lines.Line2D at 0x7f3574a420d0>,
#   <matplotlib.lines.Line2D at 0x7f3574a52150>,
#   <matplotlib.lines.Line2D at 0x7f3574a52690>]}

# %%
murder_preregion_temp = murder_preregion.loc[:,'Murder']
murder_preregion_temp
# Out:
# Region
# North Central    12
# Northeast         9
# South            16
# West             13
# Name: Murder, dtype: int64

# %%
#Q1.b)i
#split the data set into test and training data
X_statedata = statedata.loc[:,['Population','Income','Illiteracy','Murder','HighSchoolGrad','Frost','Area']]
Y_statedata = statedata["LifeExp"]

# %%
#Q1.b)i
statedata_linreg_mode = LinearRegression().fit(X=X_statedata,y=Y_statedata)
print(statedata_linreg_mode.score(X_statedata,Y_statedata))
# Out:
# 0.7361562689089038

# %%
coeefficents_statedata = pandas.DataFrame(statedata_linreg_mode.coef_,X_statedata.columns,columns=['Coefficient'])
print(f'Intercept: {statedata_linreg_mode.intercept_}\tR2: {statedata_linreg_mode.score(X_statedata,Y_statedata)}')
coeefficents_statedata
# Out:
# Intercept: 70.94322411112944	R2: 0.7361562689089038
#                  Coefficient
# Population      5.180036e-05
# Income         -2.180424e-05
# Illiteracy      3.382032e-02
# Murder         -3.011232e-01
# HighSchoolGrad  4.892948e-02
# Frost          -5.735001e-03
# Area           -7.383166e-08

# %%
#Q1.b)iii
statedata.plot.scatter(x='Income',y='LifeExp')

# %%
#X_statedata_partcv1 = statedata.loc[:,['Population','Income','Illiteracy','Murder','HighSchoolGrad','Frost','Area']]

# %%
#Q1.c)i)
X_statedata_columns_partc_v1 = ['Population','Income','Illiteracy','Murder','HighSchoolGrad']
X_statedata_partcv1 = statedata.loc[:,X_statedata_columns_partc_v1]
Y_statedata_partcv1 = statedata["LifeExp"]


statedata_linreg_mode_partcv1 = LinearRegression().fit(X=X_statedata_partcv1,y=Y_statedata_partcv1)

coeefficents_statedata_partcv1 = pandas.DataFrame(statedata_linreg_mode_partcv1.coef_,X_statedata_columns_partc_v1,columns=['Coefficient'])
print(f'Intercept: {statedata_linreg_mode_partcv1.intercept_}\tR2: {statedata_linreg_mode_partcv1.score(X_statedata_partcv1,Y_statedata_partcv1)}')
coeefficents_statedata_partcv1
# Out:
# Intercept: 69.68427119673639	R2: 0.7129413466748524
#                 Coefficient
# Population         0.000071
# Income            -0.000069
# Illiteracy         0.388524
# Murder            -0.301735
# HighSchoolGrad     0.055873

# %%
#Q1.c)iii)
statedata_pred_lifeexp = statedata_linreg_mode_partcv1.predict(X_statedata_partcv1)
statedata_pred_lifeexp
# Out:
# array([68.26084659, 70.17616609, 71.12303437, 69.52290955, 71.6653568 ,
#        71.32064142, 72.15914663, 70.92466076, 70.16044914, 68.60694791,
#        71.73112998, 71.41759898, 70.31441806, 70.84298029, 72.36744279,
#        71.74840853, 69.24559978, 69.17548041, 72.01950316, 70.32177715,
#        72.47327143, 69.95954345, 72.4006242 , 69.09022865, 69.96392621,
#        71.47089548, 72.15610984, 69.73972045, 71.94255642, 71.64020382,
#        70.53062143, 70.8390409 , 69.30807692, 72.07892161, 71.18862243,
#        70.98388493, 71.8454209 , 71.57909193, 71.81092659, 69.14119179,
#        72.10584626, 69.39683776, 70.09318711, 72.12934241, 71.21335157,
#        70.06539437, 72.08793087, 70.41086756, 72.11704242, 71.06282192])

# %%
#Q1.c)iii)
pred_maxlifeexp = statedata_pred_lifeexp.argmax()
pred_minlifeexp = statedata_pred_lifeexp.argmin()
pred_maxlifeexp
pred_minlifeexp
actual_maxlifeexp = statedata['LifeExp'].argmax()
actual_minlifeexp = statedata['LifeExp'].argmin()
print(" pred_maxlifeexp ->" , pred_maxlifeexp , " pred_minlifeexp ->",pred_minlifeexp," actual_maxlifeexp ->", actual_maxlifeexp, " actual_minlifeexp -> ",actual_minlifeexp)
# Out:
#  pred_maxlifeexp -> 20  pred_minlifeexp -> 0  actual_maxlifeexp -> 10  actual_minlifeexp ->  39

# %%
#Question 2

# %%
# Question 2 climate change 
climatedata = pandas.read_csv("/content/drive/My Drive/Colab Notebooks/ClimateChange.csv")
climatedata.head()
#climatedata.size
# Out:
#    Year  Month    MEI     CO2  ...   CFC.12        TSI  Aerosols   Temp
# 0  1983      5  2.556  345.96  ...  350.113  1366.1024    0.0863  0.109
# 1  1983      6  2.167  345.52  ...  351.848  1366.1208    0.0794  0.118
# 2  1983      7  1.741  344.15  ...  353.725  1366.2850    0.0731  0.137
# 3  1983      8  1.130  342.25  ...  355.633  1366.4202    0.0673  0.176
# 4  1983      9  0.428  340.17  ...  357.465  1366.2335    0.0619  0.149
#
# [5 rows x 11 columns]

# %%
#split the data set into test and training data
X = climatedata.iloc[:,2:10]
Y = climatedata["Temp"]

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33 )

# %%
#a)
#training data
X_2006_train = climatedata.loc[(climatedata['Year']<=2006),['MEI','CO2','CH4',	'N2O'	,'CFC.11'	,'CFC.12'	,'TSI','Aerosols']]
Y_2006_train = climatedata.loc[(climatedata['Year']<=2006),'Temp']
#testing data
X_after2006_test = climatedata.loc[(climatedata['Year']>2006),['MEI','CO2','CH4',	'N2O'	,'CFC.11'	,'CFC.12'	,'TSI','Aerosols']]
Y_after2006_test = climatedata.loc[(climatedata['Year']>2006),'Temp']
X_2006_train
# Out:
#        MEI     CO2      CH4      N2O   CFC.11   CFC.12        TSI  Aerosols
# 0    2.556  345.96  1638.59  303.677  191.324  350.113  1366.1024    0.0863
# 1    2.167  345.52  1633.71  303.746  192.057  351.848  1366.1208    0.0794
# 2    1.741  344.15  1633.22  303.795  192.818  353.725  1366.2850    0.0731
# 3    1.130  342.25  1631.35  303.839  193.602  355.633  1366.4202    0.0673
# 4    0.428  340.17  1648.40  303.901  194.392  357.465  1366.2335    0.0619
# ..     ...     ...      ...      ...      ...      ...        ...       ...
# 279  0.759  380.45  1762.66  319.930  248.981  539.682  1365.7067    0.0041
# 280  0.793  378.92  1776.04  320.010  248.775  539.566  1365.8419    0.0043
# 281  0.892  379.16  1789.02  320.125  248.666  539.488  1365.8270    0.0044
# 282  1.292  380.18  1791.91  320.321  248.605  539.500  1365.7039    0.0049
# 283  0.951  381.79  1795.04  320.451  248.480  539.377  1365.7087    0.0054
#
# [284 rows x 8 columns]

# %%
#2.a) i) && ii)
linreg_climatedata_2ai = LinearRegression().fit(X=X_2006_train,y=Y_2006_train)
#print(linreg_climatedata_2ai.score(X_2006_train,Y_2006_train))
print(f'Intercept: {linreg_climatedata_2ai.intercept_}\tR2: {linreg_climatedata_2ai.score(X_2006_train,Y_2006_train)}')
coeefficents_climatedata_2ai = pandas.DataFrame(linreg_climatedata_2ai.coef_,X_2006_train.columns,columns=['Coefficient'])
coeefficents_climatedata_2ai
# Out:
# Intercept: -124.59426040111505	R2: 0.7508932770523477
#           Coefficient
# MEI          0.064205
# CO2          0.006457
# CH4          0.000124
# N2O         -0.016528
# CFC.11      -0.006630
# CFC.12       0.003808
# TSI          0.093141
# Aerosols    -1.537613

# %%
#2.a.iv)
X_2006_train.corr()
# Out:
#                MEI       CO2       CH4  ...    CFC.12       TSI  Aerosols
# MEI       1.000000 -0.041147 -0.033419  ...  0.008286 -0.154492  0.340238
# CO2      -0.041147  1.000000  0.877280  ...  0.852690  0.177429 -0.356155
# CH4      -0.033419  0.877280  1.000000  ...  0.963616  0.245528 -0.267809
# N2O      -0.050820  0.976720  0.899839  ...  0.867931  0.199757 -0.337055
# CFC.11    0.069000  0.514060  0.779904  ...  0.868985  0.272046 -0.043921
# CFC.12    0.008286  0.852690  0.963616  ...  1.000000  0.255303 -0.225131
# TSI      -0.154492  0.177429  0.245528  ...  0.255303  1.000000  0.052117
# Aerosols  0.340238 -0.356155 -0.267809  ... -0.225131  0.052117  1.000000
#
# [8 rows x 8 columns]

# %%
#2.b.i)
X_columns_partcv1 = ['MEI','N2O','TSI','Aerosols']
#training data
X_2006_train_partcv1 = climatedata.loc[(climatedata['Year']<=2006),X_columns_partcv1]
Y_2006_train_partcv1 = climatedata.loc[(climatedata['Year']<=2006),'Temp']
#testing data
X_after2006_test_partcv1 = climatedata.loc[(climatedata['Year']>2006),X_columns_partcv1]
Y_after2006_test_partcv1 = climatedata.loc[(climatedata['Year']>2006),'Temp']


linreg_climatedata_v1_partcv1 = LinearRegression().fit(X=X_2006_train_partcv1,y=Y_2006_train_partcv1)
print(f'Intercept: {linreg_climatedata_v1_partcv1.intercept_}\tR2: {linreg_climatedata_v1_partcv1.score(X_2006_train_partcv1,Y_2006_train_partcv1)}')

coeefficents_climatedata_v1_partcv1 = pandas.DataFrame(linreg_climatedata_v1_partcv1.coef_,X_2006_train_partcv1.columns,columns=['Coefficient'])
coeefficents_climatedata_v1_partcv1
# Out:
# Intercept: -116.2268581530767	R2: 0.7261321279511104
#           Coefficient
# MEI          0.064186
# N2O          0.025320
# TSI          0.079490
# Aerosols    -1.701737

# %%
#2.c)
linreg_climatedata_partc_testdata = LinearRegression().fit(X=X_2006_train_partcv1,y=Y_2006_train_partcv1)
print(f'Intercept: {linreg_climatedata_partc_testdata.intercept_}\tR2: {linreg_climatedata_partc_testdata.score(X_after2006_test_partcv1,Y_after2006_test_partcv1)}')

coeefficents_climatedata_v1 = pandas.DataFrame(linreg_climatedata_partc_testdata.coef_,X_after2006_test_partcv1.columns,columns=['Coefficient'])
coeefficents_climatedata_v1
# Out:
# Intercept: -116.2268581530767	R2: -0.1023763906271542
#           Coefficient
# MEI          0.064186
# N2O          0.025320
# TSI          0.079490
# Aerosols    -1.701737
